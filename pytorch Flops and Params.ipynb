# %%
#安装pytorch版 efficientnet
# !pip install efficientnet_pytorch
# !pip install torchstat
# Out:
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.0-cp36-none-any.whl size=16031 sha256=67de4e0c8d4b4df23232bcf621a247d09f3d2282a1bb9feab4e1c92505126b22
#   Stored in directory: /root/.cache/pip/wheels/e9/c6/e1/7a808b26406239712cfce4b5ceeb67d9513ae32aa4b31445c6
# Successfully built efficientnet-pytorch
# ...

# %%
#显卡信息
# !nvidia-smi
# Out:
# Thu Dec  3 07:45:50 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#加载对比模型
import torchvision
from efficientnet_pytorch import EfficientNet
resnet50 = torchvision.models.resnet50(pretrained=True)
densenet169 = torchvision.models.densenet169(pretrained=True)
alexnet = torchvision.models.alexnet(pretrained=True)
vgg16 = torchvision.models.vgg16(pretrained=True)
googlenet = torchvision.models.googlenet(pretrained=True)
efficientnetB0 = EfficientNet.from_pretrained('efficientnet-b0')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...
# Downloading: "https://download.pytorch.org/models/densenet169-b2777c0a.pth" to /root/.cache/torch/hub/checkpoints/densenet169-b2777c0a.pth
# ...
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# ...
# Loaded pretrained weights for efficientnet-b0

# %%
#计算Flops和Params
from torchstat import stat
stat(efficientnetB0, (3, 416, 416))
# Out:
# [MAdd]: ZeroPad2d is not supported!
# [Flops]: ZeroPad2d is not supported!
# [Memory]: ZeroPad2d is not supported!
# [MAdd]: MemoryEfficientSwish is not supported!
# [Flops]: MemoryEfficientSwish is not supported!
# [Memory]: MemoryEfficientSwish is not supported!
# [MAdd]: ZeroPad2d is not supported!
# [Flops]: ZeroPad2d is not supported!
# [Memory]: ZeroPad2d is not supported!
# [MAdd]: MemoryEfficientSwish is not supported!
# [Flops]: MemoryEfficientSwish is not supported!
# [Memory]: MemoryEfficientSwish is not supported!
# [MAdd]: Identity is not supported!
# [Flops]: Identity is not supported!
# [Memory]: Identity is not supported!
# [MAdd]: MemoryEfficientSwish is not supported!
# [Flops]: MemoryEfficientSwish is not supported!
# [Memory]: MemoryEfficientSwish is not supported!
# [MAdd]: Identity is not supported!
# [Flops]: Identity is not supported!
# [Memory]: Identity is not supported!
# [MAdd]: Identity is not supported!
# [Flops]: Identity is not supported!
# ...

# %%
stat(resnet50, (3, 416, 416))
# Out:
# [MAdd]: AdaptiveAvgPool2d is not supported!
# [Flops]: AdaptiveAvgPool2d is not supported!
# [Memory]: AdaptiveAvgPool2d is not supported!
# [MAdd]: AdaptiveAvgPool2d is not supported!
# [Flops]: AdaptiveAvgPool2d is not supported!
# [Memory]: AdaptiveAvgPool2d is not supported!
#                  module name   input shape  output shape      params memory(MB)              MAdd             Flops  MemRead(B)  MemWrite(B) duration[%]    MemR+W(B)
# 0                      conv1     3 416 416    64 208 208      9408.0      10.56     811,286,528.0     407,027,712.0   2114304.0   11075584.0       2.86%   13189888.0
# 1                        bn1    64 208 208    64 208 208       128.0      10.56      11,075,584.0       5,537,792.0  11076096.0   11075584.0       0.35%   22151680.0
# 2                       relu    64 208 208    64 208 208         0.0      10.56       2,768,896.0       2,768,896.0  11075584.0   11075584.0       0.54%   22151168.0
# ...

# %%
stat(densenet169, (3, 416, 416))
# Out:
#                                    module name   input shape  output shape      params memory(MB)              MAdd             Flops  MemRead(B)  MemWrite(B) duration[%]     MemR+W(B)
# 0                               features.conv0     3 416 416    64 208 208      9408.0      10.56     811,286,528.0     407,027,712.0   2114304.0   11075584.0       2.19%  1.318989e+07
# 1                               features.norm0    64 208 208    64 208 208       128.0      10.56      11,075,584.0       5,537,792.0  11076096.0   11075584.0       0.30%  2.215168e+07
# 2                               features.relu0    64 208 208    64 208 208         0.0      10.56       2,768,896.0       2,768,896.0  11075584.0   11075584.0       0.11%  2.215117e+07
# 3                               features.pool0    64 208 208    64 104 104         0.0       2.64       5,537,792.0       2,768,896.0  11075584.0    2768896.0       3.43%  1.384448e+07
# ...

# %%
stat(efficientnetB0, (3, 224, 224))
# Out:
# [MAdd]: ZeroPad2d is not supported!
# [Flops]: ZeroPad2d is not supported!
# [Memory]: ZeroPad2d is not supported!
# [MAdd]: ZeroPad2d is not supported!
# [Flops]: ZeroPad2d is not supported!
# [Memory]: ZeroPad2d is not supported!
# [MAdd]: MemoryEfficientSwish is not supported!
# [Flops]: MemoryEfficientSwish is not supported!
# [Memory]: MemoryEfficientSwish is not supported!
# [MAdd]: MemoryEfficientSwish is not supported!
# [Flops]: MemoryEfficientSwish is not supported!
# [Memory]: MemoryEfficientSwish is not supported!
# [MAdd]: ZeroPad2d is not supported!
# [Flops]: ZeroPad2d is not supported!
# [Memory]: ZeroPad2d is not supported!
# [MAdd]: ZeroPad2d is not supported!
# [Flops]: ZeroPad2d is not supported!
# [Memory]: ZeroPad2d is not supported!
# [MAdd]: MemoryEfficientSwish is not supported!
# [Flops]: MemoryEfficientSwish is not supported!
# [Memory]: MemoryEfficientSwish is not supported!
# [MAdd]: MemoryEfficientSwish is not supported!
# ...
